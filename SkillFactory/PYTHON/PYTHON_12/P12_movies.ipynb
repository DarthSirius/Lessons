# %%
import pandas as pd
movies = pd.read_csv('data/movies.csv')
dates = pd.read_csv('data/dates.csv')
ratings1 = pd.read_csv('data/ratings1.csv')
ratings2 = pd.read_csv('data/ratings2.csv')

# %%
ratings1.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
ratings1['userId'].nunique()
# Out:
# 274

# %%
Year = pd.to_datetime(dates['date']).dt.year
Year.mode()
# Out:
# 0    2000
# Name: date, dtype: int64

# %%
ratings = pd.concat([ratings1, ratings2], ignore_index=True)
ratings
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
print('Число строк в таблице ratings: ', ratings.shape[0])
print('Число строк в таблице dates: ', dates.shape[0])
print(ratings.shape[0] == dates.shape[0])
# Out:
# Число строк в таблице ratings:  100837
# Число строк в таблице dates:  100836
# False

# %%
ratings = ratings.drop_duplicates(ignore_index=True)
print('Число строк в таблице ratings: ', ratings.shape[0])
# Out:
# Число строк в таблице ratings:  100836

# %%
ratings_dates = pd.concat([ratings, dates], axis=1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                 date
# 100829     610   164179     5.0  2017-05-03 21:07:11
# 100830     610   166528     4.0  2017-05-04 06:29:25
# 100831     610   166534     4.0  2017-05-03 21:53:22
# 100832     610   168248     5.0  2017-05-03 22:21:31
# 100833     610   168250     5.0  2017-05-08 19:50:47
# 100834     610   168252     5.0  2017-05-03 21:19:12
# 100835     610   170875     3.0  2017-05-03 21:20:15

# %%
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                 date  movieId_right  \
# 0            1        1     4.0  2000-07-30 18:45:03            1.0
# 1            1        3     4.0  2000-07-30 18:20:47            2.0
# 2            1        6     4.0  2000-07-30 18:37:04            3.0
# 3            1       47     5.0  2000-07-30 19:03:35            4.0
# 4            1       50     5.0  2000-07-30 18:48:51            5.0
# ...        ...      ...     ...                  ...            ...
# 100831     610   166534     4.0  2017-05-03 21:53:22            NaN
# 100832     610   168248     5.0  2017-05-03 22:21:31            NaN
# 100833     610   168250     5.0  2017-05-08 19:50:47            NaN
# 100834     610   168252     5.0  2017-05-03 21:19:12            NaN
# 100835     610   170875     3.0  2017-05-03 21:20:15            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# ...

# %%
joined_right = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='right'
)
display(joined_right)
# Out:
#       userId  movieId  rating                 date  movieId_right  \
# 0          1        1     4.0  2000-07-30 18:45:03              1
# 1          1        3     4.0  2000-07-30 18:20:47              2
# 2          1        6     4.0  2000-07-30 18:37:04              3
# 3          1       47     5.0  2000-07-30 19:03:35              4
# 4          1       50     5.0  2000-07-30 18:48:51              5
# ...      ...      ...     ...                  ...            ...
# 9737      64     3481     4.0  2006-10-22 12:37:45         193581
# 9738      64     3489     3.0  2006-10-22 23:28:09         193583
# 9739      64     3499     4.5  2006-10-22 23:26:41         193585
# 9740      64     3510     3.0  2006-10-22 23:27:26         193587
# 9741      64     3526     4.0  2006-10-23 01:23:47         193609
#
#                                           title  \
# 0                              Toy Story (1995)
# 1                                Jumanji (1995)
# ...

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
joined
# Out:
#         userId  movieId  rating                 date  \
# 0            1        1     4.0  2000-07-30 18:45:03
# 1            1        3     4.0  2000-07-30 18:20:47
# 2            1        6     4.0  2000-07-30 18:37:04
# 3            1       47     5.0  2000-07-30 19:03:35
# 4            1       50     5.0  2000-07-30 18:48:51
# ...        ...      ...     ...                  ...
# 100831     610   166534     4.0  2017-05-03 21:53:22
# 100832     610   168248     5.0  2017-05-03 22:21:31
# 100833     610   168250     5.0  2017-05-08 19:50:47
# 100834     610   168252     5.0  2017-05-03 21:19:12
# 100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100831                    Split (2017)
# ...

# %%
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)
merged
# Out:
#         userId  movieId  rating                 date  \
# 0            1        1     4.0  2000-07-30 18:45:03
# 1            1        3     4.0  2000-07-30 18:20:47
# 2            1        6     4.0  2000-07-30 18:37:04
# 3            1       47     5.0  2000-07-30 19:03:35
# 4            1       50     5.0  2000-07-30 18:48:51
# ...        ...      ...     ...                  ...
# 100831     610   166534     4.0  2017-05-03 21:53:22
# 100832     610   168248     5.0  2017-05-03 22:21:31
# 100833     610   168250     5.0  2017-05-08 19:50:47
# 100834     610   168252     5.0  2017-05-03 21:19:12
# 100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100831                    Split (2017)
# ...

# %%
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
import pandas as pd
movies = pd.read_csv('data/ratings_movies.csv')

# %%
movies
# Out:
#         Unnamed: 0  userId  movieId  rating                 date  \
# 0                0       1        1     4.0  2000-07-30 18:45:03
# 1                1       1        3     4.0  2000-07-30 18:20:47
# 2                2       1        6     4.0  2000-07-30 18:37:04
# 3                3       1       47     5.0  2000-07-30 19:03:35
# 4                4       1       50     5.0  2000-07-30 18:48:51
# ...            ...     ...      ...     ...                  ...
# 100831      100831     610   166534     4.0  2017-05-03 21:53:22
# 100832      100832     610   168248     5.0  2017-05-03 22:21:31
# 100833      100833     610   168250     5.0  2017-05-08 19:50:47
# 100834      100834     610   168252     5.0  2017-05-03 21:19:12
# 100835      100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# ...

# %%
movies['year_release'] = movies['title'].apply(get_year_release)
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    100836 non-null  int64
#  1   userId        100836 non-null  int64
#  2   movieId       100836 non-null  int64
#  3   rating        100836 non-null  float64
#  4   date          100836 non-null  datetime64[ns]
#  5   title         100836 non-null  object
#  6   genres        100836 non-null  object
#  7   year_release  100818 non-null  float64
#  8   year_rating   100836 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
movies[movies['year_release'] == 1999 ].groupby(['title']).mean().sort_values(by='rating')
# Out:
#                                             Unnamed: 0  userId   movieId  \
# title
# Bloodsport: The Dark Kumite (1999)            100797.0   610.0  145951.0
# Simon Sez (1999)                               69111.0   448.0    2887.0
# Chill Factor (1999)                            63247.0   414.0    2835.0
# Source, The (1999)                             96746.0   603.0    2813.0
# Trippin' (1999)                                89033.0   575.0    2623.0
# ...                                                ...     ...       ...
# Trailer Park Boys (1999)                       78223.0   484.0   93320.0
# Larry David: Curb Your Enthusiasm (1999)       65883.0   424.0  136469.0
# Sun Alley (Sonnenallee) (1999)                 13767.0    89.0   53355.0
# George Carlin: You Are All Diseased (1999)     16869.0   105.0  136447.0
# Five Senses, The (1999)                        17036.0   108.0    3795.0
#
#                                             rating  year_release
# title
# ...

# %%
movies[movies['year_release'] == 2010 ].groupby(['genres']).mean().sort_values(by='rating')
# Out:
#                                      Unnamed: 0      userId   movieId  \
# genres
# Action|Sci-Fi                      30179.000000  210.000000  189547.0
# Action|Adventure|Horror            58805.000000  382.000000   93139.0
# Action|Drama|Fantasy               69997.000000  448.000000   91273.0
# Crime|Romance                      69905.000000  448.000000   82093.0
# Adventure|Comedy|Fantasy           44756.333333  291.333333   82854.0
# ...                                         ...         ...       ...
# Crime                               5713.500000   40.000000  185135.0
# Comedy|Musical                     25753.000000  177.000000   93008.0
# Animation|Drama|Fantasy|Mystery    56127.000000  371.000000  112512.0
# Adventure|Children|Comedy|Mystery  13843.000000   89.000000   85295.0
# Animation|Children|Mystery         13930.000000   89.000000  118894.0
#
#                                      rating  year_release
# genres
# ...

# %%
movies.groupby('userId')['genres'].nunique().sort_values(ascending=False)
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %%
movies.groupby(['userId'])['rating'].agg(['count','mean']).sort_values(['count','mean'], ascending = [True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %%
aggr = movies[movies['year_release'] == 2018 ].groupby(['genres'])['rating'].agg('describe').sort_values('mean', ascending = False)
aggr[aggr['count'] > 10]
# Out:
#                          count      mean       std  min    25%   50%    75%  \
# genres
# Action|Adventure|Sci-Fi   14.0  3.928571  1.141139  1.5  3.250  4.25  4.875
# Action|Comedy|Sci-Fi      12.0  3.875000  1.227062  1.0  3.375  4.00  5.000
#
#                          max
# genres
# Action|Adventure|Sci-Fi  5.0
# Action|Comedy|Sci-Fi     5.0

# %%
movies.tail()
# Out:
#         Unnamed: 0  userId  movieId  rating                date  \
# 100831      100831     610   166534     4.0 2017-05-03 21:53:22
# 100832      100832     610   168248     5.0 2017-05-03 22:21:31
# 100833      100833     610   168250     5.0 2017-05-08 19:50:47
# 100834      100834     610   168252     5.0 2017-05-03 21:19:12
# 100835      100835     610   170875     3.0 2017-05-03 21:20:15
#
#                                  title                       genres  \
# 100831                    Split (2017)        Drama|Horror|Thriller
# 100832   John Wick: Chapter Two (2017)        Action|Crime|Thriller
# 100833                  Get Out (2017)                       Horror
# 100834                    Logan (2017)                Action|Sci-Fi
# 100835  The Fate of the Furious (2017)  Action|Crime|Drama|Thriller
#
#         year_release  year_rating
# 100831        2017.0         2017
# 100832        2017.0         2017
# 100833        2017.0         2017
# ...

# %%
movies['date'] = pd.to_datetime(movies['date'])
movies['year_rating'] = movies['date'].dt.year

# %%
pivot = movies.pivot_table(
    index = 'year_rating',
    columns='genres',
    values='rating',
    aggfunc='mean'
)
pivot['Action|Adventure'].min()
# Out:
# 3.2777777777777777

# %%
pivot['Action|Adventure|Animation|Children|Comedy|IMAX'].sort_values(ascending=False)
# Out:
# year_rating
# 2013    5.000000
# 2018    3.700000
# 2016    3.666667
# 2012    3.550000
# 2010    3.500000
# 2014    3.500000
# 2015    3.375000
# 2009    3.250000
# 2017    1.000000
# 1996         NaN
# 1997         NaN
# 1998         NaN
# 1999         NaN
# 2000         NaN
# 2001         NaN
# 2002         NaN
# 2003         NaN
# 2004         NaN
# 2005         NaN
# 2006         NaN
# 2007         NaN
# 2008         NaN
# 2011         NaN
# Name: Action|Adventure|Animation|Children|Comedy|IMAX, dtype: float64

# %%
t2 = pivot.loc[2018].sort_values(ascending=False)
t2.loc['Animation|Children|Mystery'] == t2.iloc[0]
# Out:
# True

# %%
pivot['Comedy']
# Out:
# year_rating
# 1996    3.228571
# 1997    3.409091
# 1998    3.000000
# 1999    3.606061
# 2000    3.141291
# 2001    3.318408
# 2002    3.198556
# 2003    3.120066
# 2004    3.356877
# 2005    2.963325
# 2006    3.347534
# 2007    2.928187
# 2008    3.426667
# 2009    3.273292
# 2010    3.179825
# 2011    3.232877
# 2012    3.478477
# 2013    3.489474
# 2014    3.271429
# 2015    3.106183
# 2016    3.373431
# 2017    2.852668
# 2018    3.121296
# Name: Comedy, dtype: float64
