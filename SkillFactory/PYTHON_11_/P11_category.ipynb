# %%
import pandas as pd
melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')
melb_df = melb_data.copy()
# создаём пустой список
unique_list = []
# пробегаемся по именам столбцов в таблице
for col in melb_df.columns:
    # создаём кортеж (имя столбца, число уникальных значений)
    item = (col, melb_df[col].nunique(),melb_df[col].dtype) 
    # добавляем кортеж в список
    unique_list.append(item) 
# создаём вспомогательную таблицу и сортируем её
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
# выводим её на экран
display(unique_counts)
# Out:
#       Column_Name  Num_Unique     Type
# 0            Type           3   object
# 1          Method           5   object
# 2      Regionname           8   object
# 3           Rooms           9    int64
# 4        Bathroom           9    int64
# 5             Car          11    int64
# 6         Bedroom          12    int64
# 7     CouncilArea          33   object
# 8            Date          58   object
# 9       YearBuilt         144    int64
# 10       Postcode         198    int64
# 11       Distance         202  float64
# 12        SellerG         268   object
# 13  Propertycount         311    int64
# 14         Suburb         314   object
# 15   BuildingArea         602  float64
# 16       Landsize        1448  float64
# 17          Price        2204  float64
# 18      Lattitude        6503  float64
# 19     Longtitude        7063  float64
# 20    Coordinates       13097   object
# 21        Address       13378   object
# 22          index       13580    int64

# %%
melb_df['Regionname'].cat.categories
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Ustenko-S\Repo\SkillFactory\PYTHON_11_\P11_category.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ustenko-S/Repo/SkillFactory/PYTHON_11_/P11_category.ipynb#ch0000001?line=0'>1</a> melb_df['Regionname'].cat.categories
#
# File d:\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File d:\Python\Python310\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File d:\Python\Python310\lib\site-packages\pandas\core\arrays\categorical.py:2717, in CategoricalAccessor.__init__(self, data)
#    2716 def __init__(self, data):
# -> 2717     self._validate(data)
#    2718     self._parent = data.values
#    2719     self._index = data.index
#
# File d:\Python\Python310\lib\site-packages\pandas\core\arrays\categorical.py:2726, in CategoricalAccessor._validate(data)
#    2723 @staticmethod
#    2724 def _validate(data):
#    2725     if not is_categorical_dtype(data.dtype):
# -> 2726         raise AttributeError("Can only use .cat accessor with a 'category' dtype")
#
# AttributeError: Can only use .cat accessor with a 'category' dtype
