# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('data/yar_vil.csv',sep=";", encoding='cp1251')
data.head()
# Out:
#    N                          uezd                  volost
# 0  9              Пошехонский уезд      Ериловская волость  \
# 1  8                Угличский уезд     Ермоловская волость
# 2  5                Рыбинский уезд   Болобановская волость
# 3  0                Рыбинский уезд    Георгиевская волость
# 4  9  Романово-Борисоглебский уезд     Рыжиковская волость
#
#                             name_0                         unit   n1  n2 n3
# 0                 лес. стр. Филино                          NaN  NaN  85  —  \
# 1            зав. "пуст. Лопенино"                          NaN  NaN  67  —
# 2  мон. "Югская Дорофеева Пустынь"                          NaN  NaN  48  —
# 3                     д. Абакумово                          NaN   47  43  —
# 4                    д. Абакумово   XIII. Прокунинское общество   85  48  6
#
#   n4   n5  ...  a6  dor  a7 type1  type2  type3 fromant antr comment
# 0  —  NaN  ... NaN  NaN NaN     х      д    NaN     NaN  NaN     NaN  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10234 entries, 0 to 10233
# Data columns (total 40 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            10234 non-null  int64
#  1   uezd         10234 non-null  object
#  2   volost       10234 non-null  object
#  3   name_0       10234 non-null  object
#  4   unit         8854 non-null   object
#  5   n1           9546 non-null   object
#  6   n2           10220 non-null  object
#  7   n3           10223 non-null  object
#  8   n4           10223 non-null  object
#  9   n5           2931 non-null   object
#  10  prihod       9493 non-null   object
#  11  a1           0 non-null      float64
#  12  a2           0 non-null      float64
#  13  a3           1 non-null      object
#  14  a4           0 non-null      float64
#  15  a5           0 non-null      float64
#  16  record_text  10233 non-null  object
#  17  name_1       10111 non-null  object
# ...

# %%
((data['name_1'].value_counts().values) == 1).sum()
# Out:
# 5581
